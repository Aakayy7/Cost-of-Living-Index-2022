# %% [markdown]
# # Cost of Living Analysis-Visualizations
#
# Cost of Living Index (Excl. Rent) is a relative indicator of consumer goods prices, including groceries, restaurants, transportation and utilities. Cost of Living Index does not include accommodation expenses such as rent or mortgage. If a city has a Cost of Living Index of 120, it means Numbeo has estimated it is 20% more expensive than New York (excluding rent).

# %%
# Import Librarys

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploring the Data

# %%
df = pd.read_csv("Cost_of_Living_Index_2022.csv")
df
# Out:
#      Rank      Country  Cost of Living Index  Rent Index  \
# 0       1  Afghanistan                 20.37        2.72
# 1       2      Albania                 35.50        8.47
# 2       3      Algeria                 26.87        4.59
# 3       4    Argentina                 34.69        7.71
# 4       5      Armenia                 33.89       11.61
# ..    ...          ...                   ...         ...
# 134   135    Venezuela                 43.20        9.99
# 135   136      Vietnam                 37.48       13.22
# 136   137        Yemen                 53.14        6.71
# 137   138       Zambia                 33.04        9.26
# 138   139     Zimbabwe                 45.68        8.75
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                             12.09            14.92                   12.41
# 1                             22.83            29.32                   25.82
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            139 non-null    int64
#  1   Country                         139 non-null    object
#  2   Cost of Living Index            139 non-null    float64
#  3   Rent Index                      139 non-null    float64
#  4   Cost of Living Plus Rent Index  139 non-null    float64
#  5   Groceries Index                 139 non-null    float64
#  6   Restaurant Price Index          139 non-null    float64
#  7   Local Purchasing Power Index    139 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 8.8+ KB

# %%
df.describe()
# Out:
#              Rank  Cost of Living Index  Rent Index  \
# count  139.000000            139.000000  139.000000
# mean    70.000000             50.188633   19.291511
# std     40.269923             20.860222   15.317726
# min      1.000000             19.920000    2.720000
# 25%     35.500000             34.715000    9.515000
# 50%     70.000000             44.680000   13.930000
# 75%    104.500000             62.580000   25.070000
# max    139.000000            146.040000   98.580000
#
#        Cost of Living Plus Rent Index  Groceries Index  \
# count                      139.000000       139.000000
# mean                        35.705324        46.637842
# std                         17.542523        20.952229
# min                         12.090000        14.920000
# 25%                         23.310000        31.200000
# 50%                         31.260000        40.220000
# 75%                         44.865000        56.590000
# ...

# %% [markdown]
# # Lets make some Analysis and Visualizations

# %%
top_10_restaurant = df.sort_values(by = ['Restaurant Price Index'],ascending=False).head(10)
lowest_10_restaurant = df.sort_values(by = ['Restaurant Price Index'],ascending=True).head(10)

top_10_groceries = df.sort_values(by = ['Groceries Index'],ascending=False).head(10)
lowest_10_groceries = df.sort_values(by = ['Groceries Index'],ascending=True).head(10)

top_10_rent = df.sort_values(by = ['Rent Index'],ascending=False).head(10)
lowest_10_rent = df.sort_values(by = ['Rent Index'],ascending=True).head(10)

top_10_costofliving = df.sort_values(by = ['Cost of Living Index'],ascending=False).head(10)
lowest_10_costofliving = df.sort_values(by = ['Cost of Living Index'],ascending=True).head(10)

top_10_power = df.sort_values(by = ['Local Purchasing Power Index'],ascending=False).head(10)
lowest_10_power = df.sort_values(by = ['Local Purchasing Power Index'],ascending=True).head(10)

# %% [markdown]
# # Top 10 countries with the highest average restaurant prices

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=top_10_restaurant['Country'], y=top_10_restaurant['Restaurant Price Index'])
plt.xticks(rotation= 45)
plt.xlabel('Country')
plt.ylabel('Restaurant Price Index')
plt.title('Top 10 countries with the highest average restaurant prices')
# Out:
# Text(0.5, 1.0, 'Top 10 countries with the highest average restaurant prices')

# %% [markdown]
# # 10 countries with the Lowest average restaurant prices

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=lowest_10_restaurant['Country'], y=lowest_10_restaurant['Restaurant Price Index'])
plt.xticks(rotation= 45)
plt.xlabel('Country')
plt.ylabel('Restaurant Price Index')
plt.title('Top 10 countries with the lowest average restaurant prices')
# Out:
# Text(0.5, 1.0, 'Top 10 countries with the lowest average restaurant prices')

# %% [markdown]
# # Top 10 countries with the highest average Groceries prices

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=top_10_groceries['Country'], y=top_10_groceries['Groceries Index'])
plt.xticks(rotation= 45)
plt.xlabel('Country')
plt.ylabel('Groceries Index')
plt.title('Top 10 countries with the highest Groceries prices')
# Out:
# Text(0.5, 1.0, 'Top 10 countries with the highest Groceries prices')

# %% [markdown]
# # 10 countries with the lowest average Groceries prices

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=lowest_10_groceries['Country'], y=lowest_10_groceries['Groceries Index'])
plt.xticks(rotation= 45)
plt.xlabel('Country')
plt.ylabel('Groceries Index')
plt.title('10 countries with the lowest Groceries prices')
# Out:
# Text(0.5, 1.0, '10 countries with the lowest Groceries prices')

# %% [markdown]
# # Top 10 Countries with the Highest Rent Prices

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=top_10_rent['Country'], y=top_10_rent['Rent Index'])
plt.xticks(rotation= 45)
plt.xlabel('Country')
plt.ylabel('Rent Index')
plt.title('Top 10 countries with the highest Rent prices')
# Out:
# Text(0.5, 1.0, 'Top 10 countries with the highest Rent prices')

# %% [markdown]
# # 10 Countries with the Lowest Rent Prices

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=lowest_10_rent['Country'], y=lowest_10_rent['Rent Index'])
plt.xticks(rotation= 45)
plt.xlabel('Country')
plt.ylabel('Rent Index')
plt.title('Top 10 countries with the lowest Rent prices')
# Out:
# Text(0.5, 1.0, 'Top 10 countries with the lowest Rent prices')

# %% [markdown]
# # Top 10 Countries with the Highest Cost of Living

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=top_10_costofliving['Country'], y=top_10_costofliving['Cost of Living Index'])
plt.xticks(rotation= 45)
plt.xlabel('Country')
plt.ylabel('Cost of Living Index')
plt.title('Top 10 countries with the highest Cost of Living ')
# Out:
# Text(0.5, 1.0, 'Top 10 countries with the highest Cost of Living ')

# %% [markdown]
# # 10 Countries with the Lowest Cost of Living

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=lowest_10_costofliving['Country'], y=lowest_10_costofliving['Cost of Living Index'])
plt.xticks(rotation= 45)
plt.xlabel('Country')
plt.ylabel('Cost of Living Index')
plt.title('10 countries with the Lowest Cost of Living ')
# Out:
# Text(0.5, 1.0, '10 countries with the Lowest Cost of Living ')

# %% [markdown]
# # Top 10 Countries with the Highest Local Purchasing Power

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=top_10_power['Country'], y=top_10_power['Local Purchasing Power Index'])
plt.xticks(rotation= 45)
plt.xlabel('Country')
plt.ylabel('Local Purchasing Power Index')
plt.title('Top 10 countries with the highest Local Purchasing Power ')
# Out:
# Text(0.5, 1.0, 'Top 10 countries with the highest Local Purchasing Power ')

# %% [markdown]
# # 10 Countries with the Lowest Local Purchasing Power

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=lowest_10_power['Country'], y=lowest_10_power['Local Purchasing Power Index'])
plt.xticks(rotation= 45)
plt.xlabel('Country')
plt.ylabel('Local Purchasing Power Index')
plt.title('10 countries with the Lowest Local Purchasing Power ')
# Out:
# Text(0.5, 1.0, '10 countries with the Lowest Local Purchasing Power ')

# %% [markdown]
# # Türkiye vs Azerbaijan

# %%
# Filter data for Turkey and Azerbaijan
countries_to_compare = ['Turkey', 'Azerbaijan']
filtered_df = df[df['Country'].isin(countries_to_compare)]

# Extract column names for comparison (excluding 'Country' and 'Rank' columns)
columns_to_compare = filtered_df.columns[2:]  

# Define custom colors for the bars
colors = ['red', 'green']

# Create a grouped bar chart for comparing Turkey and Azerbaijan
fig, ax = plt.subplots(figsize=(12, 6))

bar_width = 0.35
index = np.arange(len(columns_to_compare))

for i, country in enumerate(countries_to_compare):
    values = filtered_df[filtered_df['Country'] == country][columns_to_compare].values[0]
    plt.bar(index + i * bar_width, values, bar_width, label=country , color=colors[i])

    
    
plt.xlabel('Turkey and Azerbaijan')
plt.ylabel('Values')
plt.title('Comparison of Categories for Turkey and Azerbaijan (2022)')
plt.xticks(index + bar_width / 2, columns_to_compare, rotation=45)
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Lets try to find some relations between indexes

# %%
sns.scatterplot(x=df["Restaurant Price Index"] ,y = df["Groceries Index"])
plt.title("Restaurant Price Index - Groceries Index ")
# Out:
# Text(0.5, 1.0, 'Restaurant Price Index - Groceries Index ')

# %%
sns.scatterplot(x=df["Local Purchasing Power Index"] ,y = df["Cost of Living Index"])
plt.title("Local Purchasing Power Index - Cost of Living Index ")
# Out:
# Text(0.5, 1.0, 'Local Purchasing Power Index - Cost of Living Index ')

# %%
sns.scatterplot(x=df["Rent Index"] ,y = df["Cost of Living Index"])
plt.title("Rent Index - Cost of Living Index ")
# Out:
# Text(0.5, 1.0, 'Rent Index - Cost of Living Index ')
